# %% [markdown]
# <a href="https://colab.research.google.com/github/pamruta/Colab/blob/master/Basic-Edge-Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Edge Detection in Python OpenCV using Canny**

# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
img = cv2.imread('test.jpg')
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=812x542 at 0x7F342F4E1048>

# %%
canny = cv2.Canny(img, 200, 200)
cv2_imshow(canny)
# Out:
# <PIL.Image.Image image mode=L size=812x542 at 0x7F342EC7D7B8>

# %%
# finding and drawing contours
_, contours, hierarchy = cv2.findContours(canny, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
cv2.drawContours(img, contours, -1, (255, 255, 255), 1)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=812x542 at 0x7F342EC7DC18>
